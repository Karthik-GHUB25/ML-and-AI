# %% [markdown]
# <mark>######################################### 08/09/2025 ############################
#
# <mark> ######################################### Saturday ############################

# %% [markdown]
# People Charm’, a growing company is facing a high attrition rate among their employees which in turn affects their business due to lack of expertise and experience.
#
# • Their HR department is assigned the task to reduce the attrition rate by retaining employees who are about to churn out.
# company
#
# • They need to recommend special plans or strategies which will help them to retain their employees which in turn will help them to grow bigger as a

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

dataset = pd.read_csv('/content/people (3).csv')
dataset.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
dataset.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
warnings.filterwarnings("ig")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1230013023.py in <cell line: 0>()
# ----> 1 warnings.filterwarnings("ig")
#
# NameError: name 'warnings' is not defined

# %%
dataset.shape
# Out:
# (14999, 10)

# %%
a = df.shape
print(f" Rows : {a[0]} and Columns {a[1]}")

# %%
# statistical summary

dataset.describe().T
# Out:
#                          count        mean        std    min     25%     50%  \
# satisfactoryLevel      14999.0    0.612834   0.248631   0.09    0.44    0.64
# lastEvaluation         14999.0    0.716102   0.171169   0.36    0.56    0.72
# numberOfProjects       14999.0    3.803054   1.232592   2.00    3.00    4.00
# avgMonthlyHours        14999.0  201.050337  49.943099  96.00  156.00  200.00
# timeSpent.company      14999.0    3.498233   1.460136   2.00    3.00    3.00
# workAccident           14999.0    0.144610   0.351719   0.00    0.00    0.00
# left                   14999.0    0.238083   0.425924   0.00    0.00    0.00
# promotionInLast5years  14999.0    0.021268   0.144281   0.00    0.00    0.00
#
#                           75%    max
# satisfactoryLevel        0.82    1.0
# lastEvaluation           0.87    1.0
# numberOfProjects         5.00    7.0
# avgMonthlyHours        245.00  310.0
# timeSpent.company        4.00   10.0
# workAccident             0.00    1.0
# ...

# %% [markdown]
# insights:
#
# 1. on an average an employee is getting over worker average - 201
#
# 2. satisfactory level of the employees are 60%
#
# 3. promotion in last 5 years are less

# %%
sns.distplot(dataset['satisfactoryLevel'])
plt.show() # Distriibution plot -- to see the data pattern
# Out:
# /tmp/ipython-input-1505262727.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['satisfactoryLevel'])

# %%
# density -- it shows the proportion of your
sns.kdeplot(dataset['satisfactoryLevel'])
plt.show()

# %%
sns.histplot(dataset['satisfactoryLevel'])
plt.show()

# %%
# Data cleaning
dataset.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(3008)

# %%
dataset =dataset.drop_duplicates()

# %%
dataset.shape
# Out:
# (11991, 10)

# %%
from re import L
# 1. how many employees are there in the company who are left or still in company
plt.figure(figsize =(6,4))
sns.set_style('whitegrid')

sns.countplot(
    x ='left',
    hue = 'left',
    data = dataset,
    palette= 'viridis',
    edgecolor ='black'
)

plt.title('plot 1 : attrition rate of a company', fontsize = 14, fontweight= 'bold', pad = 15)
plt.xlabel('attrition (0 = stayed), (1 -left) ', fontsize =12)
plt.ylabel('number of employees', fontsize = 12)
plt.legend(title ='ledt', loc ='upper right')
plt.tight_layout()
plt.show()

# %%
dataset['left'].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
dataset['left'].value_counts(normalize= True)*100
# Out:
# left
# 0    83.39588
# 1    16.60412
# Name: proportion, dtype: float64

# %%
# 2.  which department has most no of employees who churned out

dataset['dept'].value_counts()
# Out:
# dept
# sales          3239
# technical      2244
# support        1821
# IT              976
# RandD           694
# product_mng     686
# marketing       673
# accounting      621
# hr              601
# management      436
# Name: count, dtype: int64

# %%
plt.figure(figsize =(8,6))
sns.set_style('dark')
sns.countplot(
    x ='dept',
    hue ='left',
    data = dataset,
    palette ='Set2',
    edgecolor ='black'
)

plt.title('Plot 2 : employee attrition rate based on department', fontsize = 15, fontweight ='bold', pad = 12)

plt.xlabel('department', fontsize = 12)
plt.ylabel('number of employees', fontsize = 12)
plt.xticks(rotation = 60)
plt.legend(title = 'Attrition ( 0 stayed 1 left', loc = 'upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# insights:
#
# sales is one with the highest attrition rate
#
# managemnent is lowest

# %%
# to get exact count of people who have left from each dept


dept_data = pd.crosstab(dataset['dept'], dataset['left'])
dept_data
# Out:
# left            0    1
# dept
# IT            818  158
# RandD         609   85
# accounting    512  109
# hr            488  113
# management    384   52
# marketing     561  112
# product_mng   576  110
# sales        2689  550
# support      1509  312
# technical    1854  390

# %%
dataset['dept'].value_counts(normalize = True)*100
# Out:
# dept
# sales          27.011926
# technical      18.714036
# support        15.186390
# IT              8.139438
# RandD           5.787674
# product_mng     5.720957
# marketing       5.612543
# accounting      5.178884
# hr              5.012092
# management      3.636060
# Name: proportion, dtype: float64

# %%
leavers = dataset[dataset['left'] == 1]

dept_left = leavers['dept'].value_counts()


dept_left
# Out:
# dept
# sales          550
# technical      390
# support        312
# IT             158
# hr             113
# marketing      112
# product_mng    110
# accounting     109
# RandD           85
# management      52
# Name: count, dtype: int64

# %%
dept_left_percent = (dept_left / dept_left.sum())*100
print(dept_left_percent.sort_values(ascending = False))
# Out:
# dept
# sales          27.624309
# technical      19.588147
# support        15.670517
# IT              7.935711
# hr              5.675540
# marketing       5.625314
# product_mng     5.524862
# accounting      5.474636
# RandD           4.269211
# management      2.611753
# Name: count, dtype: float64

# %%
dept_left =dataset.groupby(by ='dept')['left'].sum()

dept_left_percent = (dept_left / dept_left.sum())*100

dept_left_percent = dept_left_percent.sort_values(ascending = False)

print(dept_left_percent)
# Out:
# dept
# sales          27.624309
# technical      19.588147
# support        15.670517
# IT              7.935711
# hr              5.675540
# marketing       5.625314
# product_mng     5.524862
# accounting      5.474636
# RandD           4.269211
# management      2.611753
# Name: left, dtype: float64

# %%
#3. what is the attrition rate of employee leaving the company having projects less than 3
projects_less_than_3 = dataset[dataset['numberOfProjects'] < 3]
attrition_rate = projects_less_than_3['left'].mean() * 100
print("Attrition rate:", attrition_rate)
# Out:
# Attrition rate: 54.171934260429836

# %%
subset = dataset[dataset['numberOfProjects'] < 3]
attrition_rate = (subset['left'].sum() / len(subset)) * 100
print(f"Attrition rate: {attrition_rate:.2f}%")
# Out:
# Attrition rate: 54.17%

# %%
dataset.shape
# Out:
# (11991, 10)

# %%
#what is attrition rate of employee having projects greater than 5

more_projects = dataset.loc[(dataset['numberOfProjects']> 5)& (dataset['left'] == 1)]

print(f" the number of people   : {len(more_projects)}"  )
print(f" percentage : {(len(more_projects)/ 11991)*100}% ")
# Out:
#  the number of people   : 516
#  percentage : 4.303227420565424%

# %%
dataset.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
# the no of project with respect to time spent in  company to find out the employees are chured or not

plt.figure(figsize =(8,8))
sns.set_style('darkgrid')
sns.barplot(
    x ='timeSpent.company',
    y = 'numberOfProjects',
    hue = 'left',
    palette= 'mako',
    edgecolor ='black',
    data = dataset
)

plt.title('Plot 4: attrition vs no project & time spend in the company', fontsize = 17, fontweight ='bold',pad=15)

plt.xlabel('time spent in company', fontweight='bold', fontsize = 12)
plt.ylabel('average no of project', fontsize = 12)
plt.legend(title ='attrition rate', loc ='upper left')
plt.show()

# %% [markdown]
# # we need to work with freshers and with mid senior level employees

# %%
# we need to work with freshers and with mid senior level employees
# 5. how salary could be reason for churn data ???

dataset['salary'].value_counts(normalize = True)*100
# Out:
# salary
# low       47.869235
# medium    43.874573
# high       8.256192
# Name: proportion, dtype: float64

# %%
# the no of project with respect to time spent in  company to find out the employees are chured or not

plt.figure(figsize =(8,8))
sns.set_style('darkgrid')
sns.countplot(
    x ='salary',

    hue = 'left',
    order =['low','medium','high'],
    palette= 'mako',
    edgecolor ='black',
    data = dataset
)

plt.title('Plot 4: attrition rate with respect to salart', fontsize = 17, fontweight ='bold',pad=15)

plt.xlabel('salarylevels', fontweight='bold', fontsize = 12)
plt.ylabel('no of employees', fontsize = 12)
plt.legend(title ='attrition rate', loc ='upper left')
plt.show()

# %%
# now compare the time spent with respect to salary

# the no of project with respect to time spent in  company to find out the employees are chured or not



plt.figure(figsize =(8,8))
sns.set_style('darkgrid')
sns.countplot(
    x ='salary',
    hue= 'timeSpent.company',
    order =['low','medium','high'],
    palette= 'mako',

    edgecolor ='black',
    data = dataset
)

plt.title('Plot 6: timespent wrt salary', fontsize = 17, fontweight ='bold',pad=15)

plt.xlabel('salary', fontweight='bold', fontsize = 12)
plt.ylabel('time spent', fontsize = 12)
plt.legend(title ='time spent in company', loc ='upper left')
plt.show()

# %%
# is there any relationship between satisticatory level and attrition

# %%
# now compare the time spent with respect to salary

# the no of project with respect to time spent in  company to find out the employees are chured or not

plt.figure(figsize =(7,7))
sns.set_style('darkgrid')
sns.boxplot(
    x ='left',
    y='satisfactoryLevel',


    palette= 'mako',

   boxprops = {'edgecolor':'black'},
  medianprops = {'color': 'red', 'linewidth': 2},
    data = dataset
)

plt.title('Plot 7: satisfactory level of employees vs attrition', fontsize = 17, fontweight ='bold',pad=15)

plt.xlabel('attrition', fontweight='bold', fontsize = 12)
plt.ylabel('satisfaction level ', fontsize = 12)
plt.legend(title ='satisfaction level', loc ='upper left')
plt.show()
# Out:
# /tmp/ipython-input-2289597471.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# /tmp/ipython-input-2289597471.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title ='satisfaction level', loc ='upper left')

# %%
# How does the last evaluation score related to Attrition
plt.figure(figsize=(5,8))
sns.kdeplot(dataset[dataset['left']== 0]['lastEvaluation'], label ='stayed', shade = True)

sns.kdeplot(dataset[dataset['left'] ==1]['lastEvaluation'], label ='left', shade = True)

plt.title('plot 8:  last evaluation  score  distribution  by attrituion')
plt.xlabel('last evaluation')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-2769358742.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset['left']== 0]['lastEvaluation'], label ='stayed', shade = True)
# /tmp/ipython-input-2769358742.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset['left'] ==1]['lastEvaluation'], label ='left', shade = True)

# %%
# does having a work accident impact the attrition??
sns.countplot(x ='workAccident', hue ='left', data =dataset)
plt.title('plot 9 : work accident vs attrition')
plt.show()

# %%
# insights : employees with accidents are not likely to leave the company

# %%
# check the coorelation between numerical features

# heatmap

numeric_dataset = dataset.select_dtypes(include = ['number'])
sns.heatmap(numeric_dataset.corr(), annot=True, cmap ='coolwarm')
plt.title('correlation matrix')
plt.show()

#  +ve positive = one varaible the other also change --- more experience ->more salary
# -ve positive - one variable incresing and other is dec --> if you watch more Tv  , scores will decre

# %%
# what  are the top 3 reasons why employees are leaving ?

#1. salary satifaction

#2. promotions are  less
#3.  employee are overworking
