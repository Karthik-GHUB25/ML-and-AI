# %% [markdown]
# # Import Libraries

# %%
# Import Libraries

import numpy as np
import statistics as stat
import matplotlib.pyplot as plt
import statistics
import pandas as pd
import seaborn as sns
import random

# %% [markdown]
# #Import the Data - Home_Data- pd.read_csv('/content/home_data.csv')

# %%
df = pd.read_csv('/content/home_data.csv')

# %% [markdown]
# #Show the First Five Records - df.head()

# %%
df.head() # Show the first 5 rows
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# #Show the Last Five Records - df.tail()

# %%
df.tail() # Show the last 5 rows
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# #Show the Datatype - df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# #Show the Statistical Summary - df.describe()

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# #Show the columns - df.columns

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# #Number of rows and columns - df.shape()

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# #Check if there are Null values and the total Null values - df.isnull().sum().sum()

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #

# %% [markdown]
# #1) How to visualize the correlation pattern in the dataset?
# Histogram
#
# **Heatmap**
#
# Scatterplot
#
# Bar plot

# %%
# Sample correlation matrix
df = pd.DataFrame(np.random.rand(10, 5), columns=list('ABCDE'))
corr_matrix = df.corr()

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #2) Which function can we use for plotting the boxplot?
# pl.boxplt()
#
# plt.bplot()
#
# sns.box()
#
# **sns.boxplot()**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = [12, 15, 14, 10, 18, 21, 13, 19, 17, 16]

# Plot boxplot
sns.boxplot(data=data)
plt.title("Boxplot of Sample Data")
plt.show()

# %% [markdown]
# #3) What insights can we extract from the boxplot?
#
# **All of the answers**
#
# 2nd quartile
#
# 3rd quartile
#
# 2nd quartile
#
# Answer
# What You Can Extract from a Boxplot:
# - Minimum value (excluding outliers)
# - 1st Quartile (Q1) – 25th percentile
# - 2nd Quartile (Q2) – Median (50th percentile)
# - 3rd Quartile (Q3) – 75th percentile
# - Maximum value (excluding outliers)
# - Outliers – points that fall outside the whiskers
# - Spread and symmetry – how skewed or balanced the data is

# %% [markdown]
# #4) In a scatter plot, what does the 'hue' parameter represent?
#
# **The color of data points based on a categorical variable**
#
# The shape of data points
#
# The size of data points
#
# The transparency of data points

# %% [markdown]
# What hue Does in a Scatter Plot:
# In libraries like Seaborn, the hue parameter is used to:
#
# - Assign different colors to data points based on the values of a categorical or numerical variable
#
# - Visually separate groups or classes in your data

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt

# Sample dataset
tips = sns.load_dataset("tips")

# Scatter plot with hue
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex")
plt.title("Tips by Gender")
plt.show()

# %% [markdown]
# #5) Which function is used in Matplotlib to add a legend to a plot?
#
# **legend()**
#
# plot_legend()
#
# show_legend()
#
# add_legend()

# %% [markdown]
# In Matplotlib, legend() is used to display a legend on the plot, which helps identify different plotted elements (like lines, bars, or scatter groups)

# %%
#import matplotlib.pyplot as plt

plt.plot([1, 2, 3], label='Line A')
plt.plot([3, 2, 1], label='Line B')
plt.legend()  # Adds the legend to the plot
plt.title("Sample Plot with Legend")
plt.show()

# %% [markdown]
# #6) How to create a subplot in a figure with three plots side by side and two rows of subplots?
#
# ax1 = fig.add_subplot(3*2)
#
# **ax1 = fig.add_subplot(2,3,1)**
#
# ax1 = fig.add_subplot(1,2,3)
#
# ax1 = fig.add_subplot(3,2,1)

# %%
#import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6))
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.set_title(f"Plot {i}")
plt.tight_layout()
plt.show()

# %% [markdown]
# #7) In a Seaborn pair plot, what does the diagonal line represent?
#
# Regression lines
#
# **Kernel density plots**
#
# Scatter plots
#
# Histograms

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt

# Load sample dataset
iris = sns.load_dataset("iris")

# Create pairplot
sns.pairplot(iris)
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #8) Which of the following code you can use for plotting the pie chart:
#
# None of the answers
#
# Both of the answers
#
# sns.pie(x)
#
# **plt.pie(x)**

# %%
import matplotlib.pyplot as plt

x = [25, 35, 40]
labels = ['A', 'B', 'C']

plt.pie(x, labels=labels, autopct='%1.1f%%')
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# #9) What is the correct way of plotting violin plot?
#
# sns.violin(data=data, y = 'price',x = 'waterfront')
#
# All of the answers
#
# **sns.violinplot(data=data, y = 'price',x= 'waterfront')**
#
# plt.violinplot(data=data, y = 'price',x='waterfront')

# %% [markdown]
# - sns.violinplot() is the Seaborn function designed specifically for creating violin plots.
#
# - It combines the features of a boxplot and a KDE (kernel density estimate) to show the distribution of the data.

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt

sns.violinplot(data=data, x='waterfront', y='price')
plt.title("Price Distribution by Waterfront Status")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3491884030.py in <cell line: 0>()
#       2 #import matplotlib.pyplot as plt
#       3
# ----> 4 sns.violinplot(data=data, x='waterfront', y='price')
#       5 plt.title("Price Distribution by Waterfront Status")
#       6 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1723 ):
#    1724
# -> 1725     p = _CategoricalPlotter(
#    1726         data=data,
#    1727         variables=dict(x=x, y=y, hue=hue),
#
# ...

# %% [markdown]
# #10) which inference is true about the below graph:

# %% [markdown]
# **Houses with 8 bedrooms are much Expensive**
#
# Houses with 6 bedrooms are cheapest.
#
# Houses with 33 bedrooms are much Expensive
#
# Houses with 3 bedrooms are much Expensive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #11) choose the correct sytax to create a boxplot:
#
# plt.boxplot(x="price")
#
# plt.box(data["price"])
#
# plt.boxplot("price")
#
# **None of the answers**

# %% [markdown]
# - plt.boxplot() expects a sequence of numerical values, not a keyword argument like x="price".
#
# - You must pass the actual data (e.g., a column from a DataFrame) directly.

# %% [markdown]
# # 12) which inference is true about the below graph:
#
# Houses with 7 bedrooms and 4 views are having maximum sqft_living
#
# **Both a and c**
#
# C.Houses with 1 bedrooms and 0 views are having minimum sqft_living
#
# Houses with 4 bedrooms and 2 views are having maximum sqft_living

# %% [markdown]
# ![image.png](data:image/png;base64,...)
